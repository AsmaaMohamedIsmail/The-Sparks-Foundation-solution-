# %% [markdown]
# <a href="https://colab.research.google.com/github/AsmaaMohamedIsmail/The-Sparks-Foundation-solution-/blob/main/%D8%A7%D8%B3%D8%AA%D8%B7%D9%84%D8%A7%D8%B9_%D8%B1%D8%A7%D9%94%D9%8A_%D8%AD%D9%88%D9%84_%D9%85%D8%A8%D8%A7%D8%AF%D8%B1%D8%A9_%D8%AF%D8%B9%D9%85_%D9%85%D9%86%D8%B3%D9%88%D8%A8%D9%8A_%D9%88%D8%B2%D8%A7%D8%B1%D8%A9_%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85_%D8%A7%D9%84%D9%85%D8%AA%D8%B9%D8%AB%D8%B1%D9%8A%D9%86%C2%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## استطلاع رأي حول مبادرة دعم منسوبي وزارة التعليم المتعثرين

# %% [markdown]
# ### import libararies:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Loading & Inespecting data:

# %%
df=pd.read_excel('/content/drive/MyDrive/استطلاع رأي حول مبادرة دعم منسوبي وزارة التعليم المتعثرين (1-274).xlsx',header=0)
df.head(5)
# Out:
#    الرقم         وقت البداية        وقت الاكتمال    الايميل  الاسم  \
# 0      4 2023-09-05 18:10:26 2023-09-05 18:12:21  anonymous    NaN
# 1      5 2023-09-05 18:11:13 2023-09-05 18:14:13  anonymous    NaN
# 2      6 2023-09-05 18:10:23 2023-09-05 18:14:53  anonymous    NaN
# 3      7 2023-09-05 18:10:24 2023-09-05 18:15:13  anonymous    NaN
# 4      8 2023-09-05 18:10:36 2023-09-05 18:15:39  anonymous    NaN
#
#    آخر وقت تعديل                    العمر: الجنس:          التخصص   \
# 0            NaN              من 40 فأعلى    male          رياضيات
# 1            NaN  من 35 إلى أقل من 40 سنة    male          علم نفس
# 2            NaN              من 40 فأعلى    male       علم اجتماع
# 3            NaN              من 40 فأعلى    male          علم نفس
# 4            NaN              من 40 فأعلى    male  دراسات اجتماعية
#
#   عدد سنوات الخبرة الوظيفية المسمى الوظيفي   \
# 0  من 15 إلى أقل من 20 سنة       معلم متقدم
# 1  من 10 إلى أقل من 15 سنة      معلم ممارس
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 64 columns):
#  #   Column                                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                      --------------  -----
#  0   الرقم                                                                                                                                                                                       274 non-null    int64
#  1   وقت البداية                                                                                                                                                                                 274 non-null    datetime64[ns]
# ...

# %%
df.shape
# Out:
# (274, 64)

# %%
df.columns
# Out:
# Index(['الرقم', 'وقت البداية', 'وقت الاكتمال', 'الايميل', 'الاسم',
#        'آخر وقت تعديل', 'العمر:', 'الجنس:', 'التخصص ',
#        'عدد سنوات الخبرة الوظيفية', 'المسمى الوظيفي ',
#        'أرى أن تشمل المبادرة جميع منسوبي وزارة التعليم (المعلمين/ المعلمات، الإداريين، الإداريات، المشرفين/ المشرفات، حراس الأمن)',
#        'أرى أن تشمل المبادرة فئة المعلمين والمعلمات على رأس العمل ',
#        'أرى أن تشمل المبادرة فئة المتقاعدين ',
#        'أرى أن تركز المبادرة على المتضررين من الكوارث، الأزمات، والحوادث',
#        'أقترح أن تقتصر المبادرة على المعلمين في القرى، الهجر والمراكز النائية  ',
#        'أرى أن تشمل المبادرة منسوبي مدارس التعليم الخاص ',
#        'أرى أن تشمل المبادرة منسوبي وزارة التعليم من المتوفين',
#        'أرى أن تقتصر المبادرة على منسوبي وزارة التعليم الذين على قيد الحياة ',
#        'تقديم خدمات التوجيه والإرشاد الأسري لمنسوبي الوزارة المتعثرين ',
#        'تخصيص "خط استشاري " لتقديم التوجيه والإرشاد المهني لمنسوبي وزارة التعليم المتعثرين ',
# ...

# %%
df['الجنس:'].value_counts().to_frame()
# Out:
#         الجنس:
# male       218
# female      56

# %% [markdown]
# - الذكور: 218
# - الإناث :65

# %%
df['الجنس:'].value_counts().to_frame().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['العمر:'].value_counts().to_frame()
# Out:
#                           العمر:
# من 40 فأعلى                  196
# من 35 إلى أقل من 40 سنة       60
# من 30 إلى أقل من 35 سنة       14
# من 25 إلى أقل من 30 سنة        4

# %%
import plotly.express as px
fig = px.bar(df, x='العمر:')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عدد سنوات الخبرة الوظيفية:

# %%
df['عدد سنوات الخبرة الوظيفية'].value_counts().to_frame()
# Out:
#                           عدد سنوات الخبرة الوظيفية
# من 20 فأكثر                                     126
# من 15 إلى أقل من 20 سنة                          62
# من 10 إلى أقل من 15 سنة                          60
# من 5 إلى أقل من 10 سنوات                         21
# 5 سنوات فأقل                                      5

# %%
fig = px.bar(df, x='عدد سنوات الخبرة الوظيفية')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## التخصصات

# %%
df['التخصص '].value_counts().to_frame()
# Out:
#                     التخصص
# لغة عربية                52
# دراسات إسلامية           49
# دراسات اجتماعية          29
# علوم                     26
# رياضيات                  25
# علوم طبيعية              19
# فنية                     10
# علم اجتماع                8
# علم نفس                   7
# تربية خاصة                4
# بدنية                     3
# لغة انجليزية              3
# لغة انجليزية              3
# English                   2
# أحياء                     2
# حاسب                      2
# اداري                     1
# اللغة الانجليزية          1
# مساعد اداري               1
# إدارة مكتبية              1
# مراقب امن                 1
# معلم لغة إنجليزية         1
# English                   1
# مساعد إداري               1
# اقتصاد منزلي              1
# تغذيه وعلوم اطعمه         1
# إدارة مكاتب               1
# علاقات عامة               1
# تجاري                     1
# طفوله                     1
# اللغة الإنجليزية          1
# حاسب                      1
# ...

# %%
fig = px.bar(df, x='التخصص ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## المسمى الوظيفي

# %%
df['المسمى الوظيفي '].value_counts().to_frame()
# Out:
#               المسمى الوظيفي
# معلم ممارس                211
# معلم متقدم                 38
# مساعد إداري                15
# إداري                       8
# معلم خبير                   2

# %%
fig = px.bar(df, x='المسمى الوظيفي ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### أرى أن تشمل المبادرة جميع منسوبي وزارة التعليم (المعلمين/ المعلمات، الإداريين، الإداريات، المشرفين/ المشرفات، حراس الأمن)

# %%
df['أرى أن تشمل المبادرة جميع منسوبي وزارة التعليم (المعلمين/ المعلمات، الإداريين، الإداريات، المشرفين/ المشرفات، حراس الأمن)'].value_counts().to_frame()
# Out:
#                 أرى أن تشمل المبادرة جميع منسوبي وزارة التعليم (المعلمين/ المعلمات، الإداريين، الإداريات، المشرفين/ المشرفات، حراس الأمن)
# موافق بشدة                                                    245
# موافق                                                          20
# محايد                                                           7
# غير موافق                                                       1
# غير موافق بشدة                                                  1

# %%
fig = px.bar(df, x='أرى أن تشمل المبادرة جميع منسوبي وزارة التعليم (المعلمين/ المعلمات، الإداريين، الإداريات، المشرفين/ المشرفات، حراس الأمن)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أرى أن تشمل المبادرة فئة المعلمين والمعلمات على رأس العمل

# %%
df['أرى أن تشمل المبادرة فئة المعلمين والمعلمات على رأس العمل '].value_counts().to_frame()
# Out:
#                 أرى أن تشمل المبادرة فئة المعلمين والمعلمات على رأس العمل
# موافق بشدة                                                    182
# محايد                                                          39
# موافق                                                          24
# غير موافق بشدة                                                 15
# غير موافق                                                      14

# %%
fig=px.bar(df,x='أرى أن تشمل المبادرة فئة المعلمين والمعلمات على رأس العمل ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أرى أن تشمل المبادرة فئة المتقاعدين

# %%
df['أرى أن تشمل المبادرة فئة المتقاعدين '].value_counts().to_frame()
# Out:
#                 أرى أن تشمل المبادرة فئة المتقاعدين
# موافق بشدة                                       190
# موافق                                             35
# محايد                                             29
# غير موافق بشدة                                    13
# غير موافق                                          7

# %%
fig=px.bar(df,x='أرى أن تشمل المبادرة فئة المتقاعدين ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أرى أن تركز المبادرة على المتضررين من الكوارث، الأزمات، والحوادث

# %%
df['أرى أن تركز المبادرة على المتضررين من الكوارث، الأزمات، والحوادث'].value_counts().to_frame()
# Out:
#                 أرى أن تركز المبادرة على المتضررين من الكوارث، الأزمات، والحوادث
# موافق بشدة                                                    173
# محايد                                                          38
# موافق                                                          37
# غير موافق بشدة                                                 15
# غير موافق                                                      11

# %%
fig=px.bar(df,x='أرى أن تركز المبادرة على المتضررين من الكوارث، الأزمات، والحوادث')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أقترح أن تقتصر المبادرة على المعلمين في القرى، الهجر والمراكز النائية

# %%
df['أقترح أن تقتصر المبادرة على المعلمين في القرى، الهجر والمراكز النائية  '].value_counts().to_frame()
# Out:
#                 أقترح أن تقتصر المبادرة على المعلمين في القرى، الهجر والمراكز النائية
# محايد                                                          97
# غير موافق بشدة                                                 71
# موافق بشدة                                                     55
# موافق                                                          26
# غير موافق                                                      25

# %%
fig=px.bar(df,x='أقترح أن تقتصر المبادرة على المعلمين في القرى، الهجر والمراكز النائية  ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### أرى أن تشمل المبادرة منسوبي مدارس التعليم الخاص

# %%
df['أرى أن تشمل المبادرة منسوبي مدارس التعليم الخاص '].value_counts().to_frame()
# Out:
#                 أرى أن تشمل المبادرة منسوبي مدارس التعليم الخاص
# موافق بشدة                                                   136
# محايد                                                         51
# موافق                                                         44
# غير موافق بشدة                                                32
# غير موافق                                                     11

# %%
fig=px.bar(df,x='أرى أن تشمل المبادرة منسوبي مدارس التعليم الخاص ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أرى أن تشمل المبادرة منسوبي وزارة التعليم من المتوفين

# %%
df['أرى أن تشمل المبادرة منسوبي وزارة التعليم من المتوفين'].value_counts().to_frame()
# Out:
#                 أرى أن تشمل المبادرة منسوبي وزارة التعليم من المتوفين
# موافق بشدة                                                    173
# محايد                                                          39
# موافق                                                          38
# غير موافق بشدة                                                 16
# غير موافق                                                       8

# %%
fig=px.bar(df,x='أرى أن تشمل المبادرة منسوبي وزارة التعليم من المتوفين')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أرى أن تقتصر المبادرة على منسوبي وزارة التعليم الذين على قيد الحياة

# %%
df['أرى أن تقتصر المبادرة على منسوبي وزارة التعليم الذين على قيد الحياة '].value_counts().to_frame()
# Out:
#                 أرى أن تقتصر المبادرة على منسوبي وزارة التعليم الذين على قيد الحياة
# موافق بشدة                                                     90
# محايد                                                          87
# غير موافق بشدة                                                 43
# موافق                                                          36
# غير موافق                                                      18

# %%
fig=px.bar(df,x='أرى أن تقتصر المبادرة على منسوبي وزارة التعليم الذين على قيد الحياة ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تقديم خدمات التوجيه والإرشاد الأسري لمنسوبي الوزارة المتعثرين

# %%
df['تقديم خدمات التوجيه والإرشاد الأسري لمنسوبي الوزارة المتعثرين '].value_counts().to_frame()
# Out:
#                 تقديم خدمات التوجيه والإرشاد الأسري لمنسوبي الوزارة المتعثرين
# موافق بشدة                                                    170
# موافق                                                          74
# محايد                                                          21
# غير موافق بشدة                                                  5
# غير موافق                                                       4

# %%
fig=px.bar(df,x='تقديم خدمات التوجيه والإرشاد الأسري لمنسوبي الوزارة المتعثرين ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تخصيص "خط استشاري " لتقديم التوجيه والإرشاد المهني لمنسوبي وزارة التعليم المتعثرين

# %%
df['تخصيص "خط استشاري " لتقديم التوجيه والإرشاد المهني لمنسوبي وزارة التعليم المتعثرين '].value_counts().to_frame()
# Out:
#                 تخصيص "خط استشاري " لتقديم التوجيه والإرشاد المهني لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                    178
# موافق                                                          65
# محايد                                                          25
# غير موافق بشدة                                                  4
# غير موافق                                                       2

# %%
fig=px.bar(df,x='تخصيص "خط استشاري " لتقديم التوجيه والإرشاد المهني لمنسوبي وزارة التعليم المتعثرين ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عقد شراكة مع صندوق تنمية الموارد البشرية (هدف)؛ لتقديم دورات  تدريبية مخصصة وموجهة لمنسوبي وزارة التعليم المتعثرين

# %%
df['عقد شراكة مع صندوق تنمية الموارد البشرية (هدف)؛ لتقديم دورات  تدريبية مخصصة وموجهة لمنسوبي وزارة التعليم المتعثرين   '].value_counts().to_frame()
# Out:
#                 عقد شراكة مع صندوق تنمية الموارد البشرية (هدف)؛ لتقديم دورات  تدريبية مخصصة وموجهة لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                    188
# موافق                                                          53
# محايد                                                          28
# غير موافق بشدة                                                  4
# غير موافق                                                       1

# %%
fig=px.bar(df,x='عقد شراكة مع صندوق تنمية الموارد البشرية (هدف)؛ لتقديم دورات  تدريبية مخصصة وموجهة لمنسوبي وزارة التعليم المتعثرين   ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تعيين مشرف صحي يتابع حالة منسوبي وزراة التعليم المتعثرين بسبب الظروف الصحية

# %%
df['تعيين مشرف صحي يتابع حالة منسوبي وزراة التعليم المتعثرين بسبب الظروف الصحية '].value_counts().to_frame()
# Out:
#                 تعيين مشرف صحي يتابع حالة منسوبي وزراة التعليم المتعثرين بسبب الظروف الصحية
# موافق بشدة                                                    211
# موافق                                                          41
# محايد                                                          17
# غير موافق                                                       3
# غير موافق بشدة                                                  2

# %%
fig=px.bar(df,x='تعيين مشرف صحي يتابع حالة منسوبي وزراة التعليم المتعثرين بسبب الظروف الصحية ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### تقديم منتجات سكنية تتناسب مع احتياجات منسوبي وزارة التعليم المتعثرين بالتعاون مع الجهات ذات العلاقة ( وزارة الشؤون البلدية والقروية والإسكان، الجمعيات الخيرية، الجمعيات الأهلية السكنية)

# %%
df['تقديم منتجات سكنية تتناسب مع احتياجات منسوبي وزارة التعليم المتعثرين بالتعاون مع الجهات ذات العلاقة ( وزارة الشؤون البلدية والقروية والإسكان، الجمعيات الخيرية، الجمعيات الأهلية السكنية) '].value_counts().to_frame()
# Out:
#                 تقديم منتجات سكنية تتناسب مع احتياجات منسوبي وزارة التعليم المتعثرين بالتعاون مع الجهات ذات العلاقة ( وزارة الشؤون البلدية والقروية والإسكان، الجمعيات الخيرية، الجمعيات الأهلية السكنية)
# موافق بشدة                                                    245
# موافق                                                          19
# محايد                                                           7
# غير موافق                                                       2
# غير موافق بشدة                                                  1

# %%
fig=px.bar(df,x='تقديم منتجات سكنية تتناسب مع احتياجات منسوبي وزارة التعليم المتعثرين بالتعاون مع الجهات ذات العلاقة ( وزارة الشؤون البلدية والقروية والإسكان، الجمعيات الخيرية، الجمعيات الأهلية السكنية) ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### منح منسوبي وزارة التعليم المتعثرين أولوية النقل الخارجي

# %%
df['منح منسوبي وزارة التعليم المتعثرين أولوية النقل الخارجي  '].value_counts().to_frame()
# Out:
#                 منح منسوبي وزارة التعليم المتعثرين أولوية النقل الخارجي
# موافق بشدة                                                    209
# موافق                                                          31
# محايد                                                          26
# غير موافق بشدة                                                  5
# غير موافق                                                       3

# %%
fig=px.bar(df,x='منح منسوبي وزارة التعليم المتعثرين أولوية النقل الخارجي  ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أن تساهم المبادرة في تغطية تكاليف النقل   والمواصلات لمنسوبي وزارة التعليم المتعثرين بسبب المواصلات

# %%
df['أن تساهم المبادرة في تغطية تكاليف النقل   والمواصلات لمنسوبي وزارة التعليم المتعثرين بسبب المواصلات '].value_counts().to_frame()
# Out:
#             أن تساهم المبادرة في تغطية تكاليف النقل   والمواصلات لمنسوبي وزارة التعليم المتعثرين بسبب المواصلات
# موافق بشدة                                                228
# موافق                                                      29
# محايد                                                      14
# غير موافق                                                   3

# %%
fig=px.bar(df,x='أن تساهم المبادرة في تغطية تكاليف النقل   والمواصلات لمنسوبي وزارة التعليم المتعثرين بسبب المواصلات ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عقد شراكات صحية مع جهات ذات العلاقة لمنسوبي وزارة التعليم المتعثرين لأسباب صحية

# %%
df['عقد شراكات صحية مع جهات ذات العلاقة لمنسوبي وزارة التعليم المتعثرين لأسباب صحية'].value_counts().to_frame()
# Out:
#                 عقد شراكات صحية مع جهات ذات العلاقة لمنسوبي وزارة التعليم المتعثرين لأسباب صحية
# موافق بشدة                                                    237
# موافق                                                          26
# محايد                                                           7
# غير موافق بشدة                                                  2
# غير موافق                                                       2

# %%
fig=px.bar(df,x='عقد شراكات صحية مع جهات ذات العلاقة لمنسوبي وزارة التعليم المتعثرين لأسباب صحية')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## إنشاء صندوق لدعم منسوبي وزارة التعليم المتعثرين

# %%
df[' إنشاء صندوق لدعم منسوبي وزارة التعليم المتعثرين'].value_counts().to_frame()
# Out:
#                  إنشاء صندوق لدعم منسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                   239
# موافق                                                         24
# محايد                                                          8
# غير موافق                                                      2
# غير موافق بشدة                                                 1

# %%
fig=px.bar(df,x=' إنشاء صندوق لدعم منسوبي وزارة التعليم المتعثرين')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## استقطاع ما لا يزيد عن 1%  من صافي الراتب لمنسوبي الوزارة الراغبين في المساهمة في صندوق دعم المتعثرين

# %%
df[' استقطاع ما لا يزيد عن 1%  من صافي الراتب لمنسوبي الوزارة الراغبين في المساهمة في صندوق دعم المتعثرين '].value_counts().to_frame()
# Out:
#                  استقطاع ما لا يزيد عن 1%  من صافي الراتب لمنسوبي الوزارة الراغبين في المساهمة في صندوق دعم المتعثرين
# موافق بشدة                                                    102
# محايد                                                          67
# موافق                                                          48
# غير موافق بشدة                                                 42
# غير موافق                                                      15

# %%
fig=px.bar(df,x=' استقطاع ما لا يزيد عن 1%  من صافي الراتب لمنسوبي الوزارة الراغبين في المساهمة في صندوق دعم المتعثرين ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عقد شراكة مع بنك التنمية الاجتماعية لتقديم قروض مالية بسداد ميسر لمنسوبي وزارة التعليم المتعثرين

# %%
df['عقد شراكة مع بنك التنمية الاجتماعية لتقديم قروض مالية بسداد ميسر لمنسوبي وزارة التعليم المتعثرين'].value_counts().to_frame()
# Out:
#             عقد شراكة مع بنك التنمية الاجتماعية لتقديم قروض مالية بسداد ميسر لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                233
# موافق                                                      30
# محايد                                                      11

# %%
fig=px.bar(df,x='عقد شراكة مع بنك التنمية الاجتماعية لتقديم قروض مالية بسداد ميسر لمنسوبي وزارة التعليم المتعثرين')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عقد شراكات مع الجمعيات الأهلية المعنية بالإسكان لمنسوبي وزارة التعليم المتعثرين

# %%
df['عقد شراكات مع الجمعيات الأهلية المعنية بالإسكان لمنسوبي وزارة التعليم المتعثرين'].value_counts().to_frame()
# Out:
#             عقد شراكات مع الجمعيات الأهلية المعنية بالإسكان لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                232
# موافق                                                      29
# محايد                                                      13

# %%
fig=px.bar(df,x='عقد شراكات مع الجمعيات الأهلية المعنية بالإسكان لمنسوبي وزارة التعليم المتعثرين')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### منح بطاقات صحية تعطي الأولوية لمنسوبي وزارة التعليم المتعثرين بسبب الحالة الصحية

# %%
df['منح بطاقات صحية تعطي الأولوية لمنسوبي وزارة التعليم المتعثرين بسبب الحالة الصحية'].value_counts().to_frame()
# Out:
#             منح بطاقات صحية تعطي الأولوية لمنسوبي وزارة التعليم المتعثرين بسبب الحالة الصحية
# موافق بشدة                                                243
# موافق                                                      19
# محايد                                                      11
# غير موافق                                                   1

# %%
fig=px.bar(df,x='منح بطاقات صحية تعطي الأولوية لمنسوبي وزارة التعليم المتعثرين بسبب الحالة الصحية')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### منح بطاقات تموين غذائي لتغطية الاحتياجات الغذائية لمنسوبي وزارة التعليم المتعثرين

# %%
df['منح بطاقات تموين غذائي لتغطية الاحتياجات الغذائية لمنسوبي وزارة التعليم المتعثرين '].value_counts().to_frame()
# Out:
#             منح بطاقات تموين غذائي لتغطية الاحتياجات الغذائية لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                241
# موافق                                                      22
# محايد                                                      10
# غير موافق                                                   1

# %%
fig=px.bar(df,x='منح بطاقات تموين غذائي لتغطية الاحتياجات الغذائية لمنسوبي وزارة التعليم المتعثرين ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تقديم دعم مالي لمنسوبي وزارة التعليم المتضررين بسبب حالات الطوارئ (الحرائق، حوادث ، سيول..الخ).

# %%
df[' تقديم دعم مالي لمنسوبي وزارة التعليم المتضررين بسبب حالات الطوارئ (الحرائق، حوادث ، سيول..الخ).  '].value_counts().to_frame()
# Out:
#                  تقديم دعم مالي لمنسوبي وزارة التعليم المتضررين بسبب حالات الطوارئ (الحرائق، حوادث ، سيول..الخ).
# موافق بشدة                                                    244
# موافق                                                          20
# محايد                                                           8
# غير موافق                                                       1
# غير موافق بشدة                                                  1

# %%
fig=px.bar(df,x=' تقديم دعم مالي لمنسوبي وزارة التعليم المتضررين بسبب حالات الطوارئ (الحرائق، حوادث ، سيول..الخ).  ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### رفع المستندات المطلوبة إلى مكتب إدارة التعليم للتقديم على الخدمة والحصول عليها

# %%
df['رفع المستندات المطلوبة إلى مكتب إدارة التعليم للتقديم على الخدمة والحصول عليها'].value_counts().to_frame()
# Out:
#                 رفع المستندات المطلوبة إلى مكتب إدارة التعليم للتقديم على الخدمة والحصول عليها
# موافق بشدة                                                    191
# محايد                                                          32
# موافق                                                          24
# غير موافق بشدة                                                 16
# غير موافق                                                      11

# %%
fig=px.bar(df,x='رفع المستندات المطلوبة إلى مكتب إدارة التعليم للتقديم على الخدمة والحصول عليها')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## التقديم على الخدمة والحصول عليها عن طريق منصة نظام نور

# %%
df['التقديم على الخدمة والحصول عليها عن طريق منصة نظام نور'].value_counts().to_frame()
# Out:
#                 التقديم على الخدمة والحصول عليها عن طريق منصة نظام نور
# موافق بشدة                                                    189
# محايد                                                          36
# موافق                                                          28
# غير موافق بشدة                                                 11
# غير موافق                                                      10

# %%
fig=px.bar(df,x='التقديم على الخدمة والحصول عليها عن طريق منصة نظام نور')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## التسجيل في منصة مخصصة للتقديم على الخدمة والحصول عليها

# %%
df['التسجيل في منصة مخصصة للتقديم على الخدمة والحصول عليها'].value_counts().to_frame()
# Out:
#                 التسجيل في منصة مخصصة للتقديم على الخدمة والحصول عليها
# موافق بشدة                                                    220
# موافق                                                          28
# محايد                                                          19
# غير موافق بشدة                                                  6
# غير موافق                                                       1

# %%
fig=px.bar(df,x='التسجيل في منصة مخصصة للتقديم على الخدمة والحصول عليها')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## طلب الخدمة والحصول عليها مباشرة عن طريق إدارة المدرسة

# %%
df['طلب الخدمة والحصول عليها مباشرة عن طريق إدارة المدرسة'].value_counts().to_frame()
# Out:
#                 طلب الخدمة والحصول عليها مباشرة عن طريق إدارة المدرسة
# موافق بشدة                                                    167
# محايد                                                          45
# موافق                                                          30
# غير موافق بشدة                                                 25
# غير موافق                                                       7

# %%
fig=px.bar(df,x='طلب الخدمة والحصول عليها مباشرة عن طريق إدارة المدرسة')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عدد سنوات الخبرة

# %%
df[' عدد سنوات الخبرة'].value_counts().to_frame()
# Out:
#                  عدد سنوات الخبرة
# موافق بشدة                    130
# محايد                          65
# موافق                          49
# غير موافق                      17
# غير موافق بشدة                 13

# %%
fig=px.bar(df,x=' عدد سنوات الخبرة')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## المسمى الوظيفي (إداري، مساعد إداري، معلم ممارس، مساعد معلم،  معلم متقدم، معلم خبير ...)

# %%
df['المسمى الوظيفي (إداري، مساعد إداري، معلم ممارس، مساعد معلم،  معلم متقدم، معلم خبير ...)'].value_counts().to_frame()
# Out:
#                 المسمى الوظيفي (إداري، مساعد إداري، معلم ممارس، مساعد معلم،  معلم متقدم، معلم خبير ...)
# موافق بشدة                                                    141
# محايد                                                          60
# موافق                                                          41
# غير موافق بشدة                                                 18
# غير موافق                                                      14

# %%
fig=px.bar(df,x='المسمى الوظيفي (إداري، مساعد إداري، معلم ممارس، مساعد معلم،  معلم متقدم، معلم خبير ...)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### صافي الراتب

# %%
df['صافي الراتب '].value_counts().to_frame()
# Out:
#                 صافي الراتب
# موافق بشدة               146
# موافق                     56
# محايد                     47
# غير موافق بشدة            18
# غير موافق                  7

# %%
fig=px.bar(df,x='صافي الراتب ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### حجم الأسرة

# %%
df['حجم الأسرة'].value_counts().to_frame()
# Out:
#                 حجم الأسرة
# موافق بشدة             184
# موافق                   51
# محايد                   29
# غير موافق بشدة           7
# غير موافق                3

# %%
fig=px.bar(df,x='حجم الأسرة')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## حجم القروض

# %%
df['حجم القروض '].value_counts().to_frame()
# Out:
#                 حجم القروض
# موافق بشدة              195
# موافق                    43
# محايد                    24
# غير موافق                 7
# غير موافق بشدة            5

# %%
fig=px.bar(df,x='حجم القروض ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### وجود قروض أو ديون متعثرة

# %%
df['وجود قروض أو ديون متعثرة '].value_counts().to_frame()
# Out:
#                 وجود قروض أو ديون متعثرة
# موافق بشدة                            204
# موافق                                  42
# محايد                                  19
# غير موافق بشدة                          7
# غير موافق                               2

# %%
fig=px.bar(df,x='وجود قروض أو ديون متعثرة ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## وجود إيقاف خدمات

# %%
df['وجود إيقاف خدمات'].value_counts().to_frame()
# Out:
#                 وجود إيقاف خدمات
# موافق بشدة                   206
# موافق                         37
# محايد                         23
# غير موافق بشدة                 6
# غير موافق                      2

# %%
fig=px.bar(df,x='وجود إيقاف خدمات')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## وجود أبناء عاطلين عن العمل

# %%
df['وجود أبناء عاطلين عن العمل'].value_counts().to_frame()
# Out:
#                 وجود أبناء عاطلين عن العمل
# موافق بشدة                             196
# موافق                                   37
# محايد                                   33
# غير موافق بشدة                           5
# غير موافق                                3

# %%
fig=px.bar(df,x='وجود أبناء عاطلين عن العمل')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عدم تملك مسكن

# %%
df['عدم تملك مسكن'].value_counts().to_frame()
# Out:
#                 عدم تملك مسكن
# موافق بشدة                209
# موافق                      35
# محايد                      25
# غير موافق بشدة              3
# غير موافق                   2

# %%
fig=px.bar(df,x='عدم تملك مسكن')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### وجود أمراض مزمنة لدى منسوب وزارة التعليم المتعثر أو لدى من يعولهم

# %%
df['وجود أمراض مزمنة لدى منسوب وزارة التعليم المتعثر أو لدى من يعولهم '].value_counts().to_frame()
# Out:
#                 وجود أمراض مزمنة لدى منسوب وزارة التعليم المتعثر أو لدى من يعولهم
# موافق بشدة                                                    228
# موافق                                                          27
# محايد                                                          17
# غير موافق بشدة                                                  2

# %%
fig=px.bar(df,x='وجود أمراض مزمنة لدى منسوب وزارة التعليم المتعثر أو لدى من يعولهم ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### لا تقل نسبة الدعم عن (5%) من صافي الراتب

# %%
df['لا تقل نسبة الدعم عن (5%) من صافي الراتب'].value_counts().to_frame()
# Out:
#                 لا تقل نسبة الدعم عن (5%) من صافي الراتب
# موافق بشدة                                           180
# موافق                                                 45
# محايد                                                 37
# غير موافق                                              7
# غير موافق بشدة                                         5

# %%
fig=px.bar(df,x='لا تقل نسبة الدعم عن (5%) من صافي الراتب')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## أن تكون الديون الأقل تكلفة (أقل من 10,000 ريال) تمنح أولوية في معايير الاستحقاق

# %%
df[' أن تكون الديون الأقل تكلفة (أقل من 10,000 ريال) تمنح أولوية في معايير الاستحقاق'].value_counts().to_frame()
# Out:
#                  أن تكون الديون الأقل تكلفة (أقل من 10,000 ريال) تمنح أولوية في معايير الاستحقاق
# موافق بشدة                                                    140
# موافق                                                          68
# محايد                                                          50
# غير موافق بشدة                                                  9
# غير موافق                                                       7

# %%
fig=px.bar(df,x=' أن تكون الديون الأقل تكلفة (أقل من 10,000 ريال) تمنح أولوية في معايير الاستحقاق')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## المساهمة في الحصول على قروض سكنية ميسرة بناءً على راتب المستفيد المتبقي

# %%
df['المساهمة في الحصول على قروض سكنية ميسرة بناءً على راتب المستفيد المتبقي'].value_counts().to_frame()
# Out:
#                 المساهمة في الحصول على قروض سكنية ميسرة بناءً على راتب المستفيد المتبقي
# موافق بشدة                                                    220
# موافق                                                          38
# محايد                                                          14
# غير موافق بشدة                                                  2

# %%
fig=px.bar(df,x='المساهمة في الحصول على قروض سكنية ميسرة بناءً على راتب المستفيد المتبقي')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### أن تكون الأولوية في الحصول على الدعم للمتعثر  بناءً على الأسرة الأكبر من حيث عدد الأفراد

# %%
df['أن تكون الأولوية في الحصول على الدعم للمتعثر  بناءً على الأسرة الأكبر من حيث عدد الأفراد'].value_counts().to_frame()
# Out:
#                 أن تكون الأولوية في الحصول على الدعم للمتعثر  بناءً على الأسرة الأكبر من حيث عدد الأفراد
# موافق بشدة                                                    187
# موافق                                                          50
# محايد                                                          33
# غير موافق بشدة                                                  3
# غير موافق                                                       1

# %%
fig=px.bar(df,x='أن تكون الأولوية في الحصول على الدعم للمتعثر  بناءً على الأسرة الأكبر من حيث عدد الأفراد')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### أن تكون الأولوية في الحصول على الدعم للمتعثر   بناءً على شدة /خطورة الحالة الصحية للمستفيد أو من يعوله

# %%
df['أن تكون الأولوية في الحصول على الدعم للمتعثر   بناءً على شدة /خطورة الحالة الصحية للمستفيد أو من يعوله'].value_counts().to_frame()
# Out:
#                 أن تكون الأولوية في الحصول على الدعم للمتعثر   بناءً على شدة /خطورة الحالة الصحية للمستفيد أو من يعوله
# موافق بشدة                                                    206
# موافق                                                          42
# محايد                                                          24
# غير موافق بشدة                                                  1
# غير موافق                                                       1

# %%
fig=px.bar(df,x='أن تكون الأولوية في الحصول على الدعم للمتعثر   بناءً على شدة /خطورة الحالة الصحية للمستفيد أو من يعوله')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## التأخر في تقديم الدعم المناسب لمنسوبي وزارة التعليم المتعثرين

# %%
df['التأخر في تقديم الدعم المناسب لمنسوبي وزارة التعليم المتعثرين'].value_counts().to_frame()
# Out:
#                 التأخر في تقديم الدعم المناسب لمنسوبي وزارة التعليم المتعثرين
# موافق بشدة                                                    177
# موافق                                                          57
# محايد                                                          29
# غير موافق بشدة                                                  6
# غير موافق                                                       5

# %%
fig=px.bar(df,x='التأخر في تقديم الدعم المناسب لمنسوبي وزارة التعليم المتعثرين')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## البيروقراطية في إجراءات التقديم للحصول على الدعم (تعقيد الإجراءات)

# %%
df['البيروقراطية في إجراءات التقديم للحصول على الدعم (تعقيد الإجراءات)'].value_counts().to_frame()
# Out:
#                 البيروقراطية في إجراءات التقديم للحصول على الدعم (تعقيد الإجراءات)
# موافق بشدة                                                    193
# موافق                                                          53
# محايد                                                          22
# غير موافق بشدة                                                  5
# غير موافق                                                       1

# %%
fig=px.bar(df,x='البيروقراطية في إجراءات التقديم للحصول على الدعم (تعقيد الإجراءات)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## حدوث مشاكل تقنية في بيانات مستحقين الدعم

# %%
df['حدوث مشاكل تقنية في بيانات مستحقين الدعم '].value_counts().to_frame()
# Out:
#                 حدوث مشاكل تقنية في بيانات مستحقين الدعم
# موافق بشدة                                            156
# موافق                                                  67
# محايد                                                  37
# غير موافق                                               7
# غير موافق بشدة                                          7

# %%
fig=px.bar(df,x='حدوث مشاكل تقنية في بيانات مستحقين الدعم ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تعدد احتياجات المستفيد من الدعم  (سكنية، صحية، اقتصادية، تأهيلية، وظيفية، لوجستية...)

# %%
df['تعدد احتياجات المستفيد من الدعم  (سكنية، صحية، اقتصادية، تأهيلية، وظيفية، لوجستية...)'].value_counts().to_frame()
# Out:
#                 تعدد احتياجات المستفيد من الدعم  (سكنية، صحية، اقتصادية، تأهيلية، وظيفية، لوجستية...)
# موافق بشدة                                                    182
# موافق                                                          57
# محايد                                                          28
# غير موافق بشدة                                                  4
# غير موافق                                                       3

# %%
fig=px.bar(df,x='تعدد احتياجات المستفيد من الدعم  (سكنية، صحية، اقتصادية، تأهيلية، وظيفية، لوجستية...)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## انخفاض القيمة المالية المخصصة لصندوق الدعم (عدم وجود سيولة)

# %%
df['انخفاض القيمة المالية المخصصة لصندوق الدعم (عدم وجود سيولة)  '].value_counts().to_frame()
# Out:
#                 انخفاض القيمة المالية المخصصة لصندوق الدعم (عدم وجود سيولة)
# موافق بشدة                                                    187
# موافق                                                          50
# محايد                                                          32
# غير موافق بشدة                                                  3
# غير موافق                                                       2

# %%
fig=px.bar(df,x='انخفاض القيمة المالية المخصصة لصندوق الدعم (عدم وجود سيولة)  ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### وجود احتياجات طارئة لدى المتعثر من منسوبي وزارة التعليم (حرائق، حوادث، كوارث ...)

# %%
df['وجود احتياجات طارئة لدى المتعثر من منسوبي وزارة التعليم (حرائق، حوادث، كوارث ...)'].value_counts().to_frame()
# Out:
#                 وجود احتياجات طارئة لدى المتعثر من منسوبي وزارة التعليم (حرائق، حوادث، كوارث ...)
# موافق بشدة                                                    184
# موافق                                                          56
# محايد                                                          24
# غير موافق بشدة                                                  7
# غير موافق                                                       3

# %%
fig=px.bar(df,x='وجود احتياجات طارئة لدى المتعثر من منسوبي وزارة التعليم (حرائق، حوادث، كوارث ...)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## تحايل بعض المتعثرين من منسوبي وزارة التعليم في شروط الاستحقاق والاحتياجات

# %%
df['تحايل بعض المتعثرين من منسوبي وزارة التعليم في شروط الاستحقاق والاحتياجات '].value_counts().to_frame()
# Out:
#                 تحايل بعض المتعثرين من منسوبي وزارة التعليم في شروط الاستحقاق والاحتياجات
# موافق بشدة                                                    156
# موافق                                                          55
# محايد                                                          45
# غير موافق بشدة                                                 11
# غير موافق                                                       7

# %%
fig=px.bar(df,x='تحايل بعض المتعثرين من منسوبي وزارة التعليم في شروط الاستحقاق والاحتياجات ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## عدم وجود الشفافية الكاملة في تقديم الخدمات للمتعثرين من منسوبي وزارة التعليم

# %%
df['عدم وجود الشفافية الكاملة في تقديم الخدمات للمتعثرين من منسوبي وزارة التعليم  '].value_counts().to_frame()
# Out:
#                 عدم وجود الشفافية الكاملة في تقديم الخدمات للمتعثرين من منسوبي وزارة التعليم
# موافق بشدة                                                    166
# موافق                                                          58
# محايد                                                          36
# غير موافق بشدة                                                  8
# غير موافق                                                       6

# %%
fig=px.bar(df,x='عدم وجود الشفافية الكاملة في تقديم الخدمات للمتعثرين من منسوبي وزارة التعليم  ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### تعفف المتعثر من الإفصاح عن احتياجاته للحصول على الدعم المناسب

# %%
df['تعفف المتعثر من الإفصاح عن احتياجاته للحصول على الدعم المناسب '].value_counts().to_frame()
# Out:
#                 تعفف المتعثر من الإفصاح عن احتياجاته للحصول على الدعم المناسب
# موافق بشدة                                                    184
# موافق                                                          48
# محايد                                                          29
# غير موافق                                                       7
# غير موافق بشدة                                                  6

# %%
fig=px.bar(df,x='تعفف المتعثر من الإفصاح عن احتياجاته للحصول على الدعم المناسب ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## التأثير السلبي للدعم على الراتب (الاستقطاع من الراتب)

# %%
df['التأثير السلبي للدعم على الراتب (الاستقطاع من الراتب)'].value_counts().to_frame()
# Out:
#                 التأثير السلبي للدعم على الراتب (الاستقطاع من الراتب)
# موافق بشدة                                                    179
# موافق                                                          61
# محايد                                                          26
# غير موافق                                                       5
# غير موافق بشدة                                                  3

# %%
fig=px.bar(df,x='التأثير السلبي للدعم على الراتب (الاستقطاع من الراتب)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## قد يعتمد منسوب وزارة التعليم المتعثر على الدعم المادي دون معالجة أسباب التعثر

# %%
df['قد يعتمد منسوب وزارة التعليم المتعثر على الدعم المادي دون معالجة أسباب التعثر'].value_counts().to_frame()
# Out:
#                 قد يعتمد منسوب وزارة التعليم المتعثر على الدعم المادي دون معالجة أسباب التعثر
# موافق بشدة                                                    167
# موافق                                                          58
# محايد                                                          36
# غير موافق بشدة                                                 10
# غير موافق                                                       3

# %%
fig=px.bar(df,x='قد يعتمد منسوب وزارة التعليم المتعثر على الدعم المادي دون معالجة أسباب التعثر')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install nbconvert[webpdf]
# Out:
# ...
#   Created wheel for websockets: filename=websockets-8.1-cp39-cp39-win_amd64.whl size=62758 sha256=d7380e03e25dcfe7dac5d4077701e2e90d3ea3d0e420362890838f590dad3238
#   Stored in directory: c:\users\dream\appdata\local\pip\cache\wheels\d8\b9\a0\b97b211aeda2ebd6ac2e43fc300d308dbf1f9df520ed390cae
# Successfully built websockets
# ...
# Note: you may need to restart the kernel to use updated packages.
